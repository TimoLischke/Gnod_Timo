# %% [raw]
# Explore the provided dataset and identify song features (such as tempo, loudness, danceability)

# %%
# import libraries
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load 100 top Billboard songs dataset 
songs_billboard = "df_song_dict_billboard.csv"
df_songs_billboard = pd.read_csv(songs_billboard)
df_songs_billboard
# Out:
#                    title                                  artist  rank
# 0                 Luther                    Kendrick Lamar & SZA     1
# 1       Die With A Smile                  Lady Gaga & Bruno Mars     2
# 2            Not Like Us                          Kendrick Lamar     3
# 3                 TV Off  Kendrick Lamar Featuring Lefty Gunplay     4
# 4     A Bar Song (Tipsy)                               Shaboozey     5
# ..                   ...                                     ...   ...
# 95               No Pole                             Don Toliver    96
# 96       Small Town Fame                                   Drake    97
# 97        Que Pasaria...              Rauw Alejandro & Bad Bunny    98
# 98            Greenlight                              Tate McRae    99
# 99  Weren't For The Wind                            Ella Langley   100
#
# [100 rows x 3 columns]

# %%
# load audio features dataset 
audio_features = "audio_features_dataset.csv"
df_audio_features = pd.read_csv(audio_features)
df_audio_features
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# Summary of the data: checking data types
column_summary_df_audio_features = pd.DataFrame({
    'Column Name': df_audio_features.columns,
    'Data Type': df_audio_features.dtypes.values,
    'Non-Null Count': df_audio_features.notnull().sum().values,
    'Null Count': df_audio_features.isnull().sum().values,
    'Data Type': df_audio_features.dtypes.values,
    'Percentage Null': df_audio_features.isnull().mean().values * 100,
    'Unique Values': df_audio_features.nunique().values
})

print(column_summary_df_audio_features)
# Out:
#          Column Name Data Type  Non-Null Count  Null Count  Percentage Null  \
# 0         Unnamed: 0     int64          114000           0         0.000000
# 1           track_id    object          114000           0         0.000000
# 2            artists    object          113999           1         0.000877
# 3         album_name    object          113999           1         0.000877
# 4         track_name    object          113999           1         0.000877
# 5         popularity     int64          114000           0         0.000000
# 6        duration_ms     int64          114000           0         0.000000
# 7           explicit      bool          114000           0         0.000000
# 8       danceability   float64          114000           0         0.000000
# 9             energy   float64          114000           0         0.000000
# 10               key     int64          114000           0         0.000000
# ...

# %%
# Summary of the data: checking numerical distribution of data
df_audio_features.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
# Creating histograms for each numerical column in 'df_audio_features' to check for distribution
df_audio_features.hist(figsize=(15, 20), bins=60, xlabelsize=10, ylabelsize=10);
plt.show()

# %%
# Check for missing values: df_audio_features
df_audio_features.isna().any()
# Out:
# Unnamed: 0          False
# track_id            False
# artists              True
# album_name           True
# track_name           True
# popularity          False
# duration_ms         False
# explicit            False
# danceability        False
# energy              False
# key                 False
# loudness            False
# mode                False
# speechiness         False
# acousticness        False
# instrumentalness    False
# liveness            False
# valence             False
# tempo               False
# time_signature      False
# dtype: bool

# %%
# Check for missing values: df_audio_features
df_audio_features.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
# As there is only three null values, these can be dropped:
df_audio_features.dropna(inplace=True)

# %%
df_audio_features.head(50)
# Out:
#     Unnamed: 0                track_id                               artists  \
# 0            0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1            1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2            2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3            3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4            4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5            5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6            6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7            7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8            8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9            9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10          10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# ...

# %%
df_audio_features.isna().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             0
# album_name          0
# track_name          0
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# dtype: int64

# %%
# Check if df is a DataFrame
isinstance(df_audio_features, pd.DataFrame)

print(df_audio_features)  # Output: True
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df_audio_features.head(50)
# Out:
#     Unnamed: 0                track_id                               artists  \
# 0            0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1            1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2            2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3            3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4            4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5            5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6            6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7            7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8            8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9            9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10          10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# ...

# %%
# Drop the Unnamed column:
df_audio_features.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# Check if df is a DataFrame
isinstance(df_audio_features, pd.DataFrame)

print(df_audio_features)  # Output: True
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df_audio_features.head(50)
# Out:
#                   track_id                               artists  \
# 0   5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1   4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2   1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3   6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4   5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5   01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6   6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7   1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8   0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9   7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# 11  5ivF4eQBqJiVL5IAE9jRyl                            Jason Mraz
# 12  4ptDJbJl35d7gQfeNteBwp                              Dan Berk
# ...

# %%
# Check for dulpicated values: df_audio_features
df_audio_features.duplicated().any()
# Out:
# True

# %%
df_audio_features.head(50)
# Out:
#                   track_id                               artists  \
# 0   5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1   4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2   1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3   6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4   5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5   01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6   6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7   1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8   0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9   7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
# 10  4mzP5mHkRvGxdhdGdAH7EJ                          Zack Tabudlo
# 11  5ivF4eQBqJiVL5IAE9jRyl                            Jason Mraz
# 12  4ptDJbJl35d7gQfeNteBwp                              Dan Berk
# ...

# %%
df_audio_features.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  113999.000000  1.139990e+05  113999.000000  113999.000000
# mean       33.238827  2.280312e+05       0.566801       0.641383
# std        22.304959  1.072961e+05       0.173543       0.251530
# min         0.000000  8.586000e+03       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  113999.000000  113999.000000  113999.000000  113999.000000
# mean        5.309126      -8.258950       0.637558       0.084652
# std         3.559999       5.029357       0.480708       0.105733
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
# Summary of the data: checking data types
column_summary_df_audio_features = pd.DataFrame({
    'Column Name': df_audio_features.columns,
    'Data Type': df_audio_features.dtypes.values,
    'Non-Null Count': df_audio_features.notnull().sum().values,
    'Null Count': df_audio_features.isnull().sum().values,
    'Data Type': df_audio_features.dtypes.values,
    'Percentage Null': df_audio_features.isnull().mean().values * 100,
    'Unique Values': df_audio_features.nunique().values
})

print(column_summary_df_audio_features)
# Out:
#          Column Name Data Type  Non-Null Count  Null Count  Percentage Null  \
# 0           track_id    object          113999           0              0.0
# 1            artists    object          113999           0              0.0
# 2         album_name    object          113999           0              0.0
# 3         track_name    object          113999           0              0.0
# 4         popularity     int64          113999           0              0.0
# 5        duration_ms     int64          113999           0              0.0
# 6           explicit      bool          113999           0              0.0
# 7       danceability   float64          113999           0              0.0
# 8             energy   float64          113999           0              0.0
# 9                key     int64          113999           0              0.0
# 10          loudness   float64          113999           0              0.0
# ...

# %%
# Check if df is a DataFrame
isinstance(df_audio_features, pd.DataFrame)

print(df_audio_features)  # Output: True
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
# Safe the updated datafile for df_audio_features dataframe:
# df_audio_features.to_csv("df_audio_features_clean.csv", index=False)
# ONLY DONE ONCE !
